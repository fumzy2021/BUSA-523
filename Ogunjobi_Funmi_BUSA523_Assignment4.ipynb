# %% [markdown]
# Using the dataset provided, develop the following visualizations using the right
# set of variables

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data_sheet = pd.read_csv('data.csv', header = 0, index_col = 0)

data_sheet
# Out:
#             Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# Date
# 5/2/2010          42.31       2.572        NaN        NaN        NaN
# 12/2/2010         38.51       2.548        NaN        NaN        NaN
# 19/02/2010        39.93       2.514        NaN        NaN        NaN
# 26/02/2010        46.63       2.561        NaN        NaN        NaN
# 5/3/2010          46.50       2.625        NaN        NaN        NaN
# ...                 ...         ...        ...        ...        ...
# 28/09/2012        76.08       3.666    3666.27       7.64       1.65
# 5/10/2012         68.55       3.617    8077.89        NaN      18.22
# 12/10/2012        62.99       3.601    2086.18        NaN       8.11
# 19/10/2012        67.97       3.594     950.33        NaN       4.93
# 26/10/2012        69.16       3.506    2585.85      31.75       6.00
#
#             MarkDown4  MarkDown5         CPI  Unemployment     Day type  \
# Date
# ...

# %% [markdown]
# a) Histogram

# %%
plt.hist(data_sheet['Temperature'])
plt.suptitle('Histogram of Temperature')
plt.xlabel('Temperature')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# b) Barchart

# %%
dataBar = pd.DataFrame(data_sheet, columns=['Unemployment'])
dataBar[0:143:25].plot.bar()
plt.suptitle('Unemployement rate over 3 years')
plt.ylabel('Unemployment rate')
# Out:
# Text(0, 0.5, 'Unemployment rate')

# %% [markdown]
# c) Line Chart

# %%
dataLine = pd.DataFrame(data_sheet, columns=['Fuel_Price'])
dataLine.plot()
plt.suptitle('Fuel Prices over the years')
plt.ylabel('Fuel Price per gallon in USD')
# Out:
# Text(0, 0.5, 'Fuel Price per gallon in USD')

# %% [markdown]
# d)Area Chart

# %%
dataArea = pd.DataFrame(data_sheet, columns=['dept_1 sales','dept_2 sales','dept_3 sales'])
dataArea.plot.area()
plt.suptitle('Sales by Department from 2010 to 2012')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# e) ScatterPlot

# %%
dataScatter = pd.DataFrame(data_sheet)
dataScatter.plot.scatter(x = 'CPI', y = 'Fuel_Price')
plt.suptitle('How CPI affects Fuel Prices')
# Out:
# Text(0.5, 0.98, 'How CPI affects Fuel Prices')

# %%
dataLine = pd.DataFrame(data_sheet, columns=['Fuel_Price'])
dataLine.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
dataBar = pd.DataFrame(data_sheet, columns=['Unemployment'])
dataBar[0:143:10].plot.bar()
# Out:
# <AxesSubplot:xlabel='Date'>
